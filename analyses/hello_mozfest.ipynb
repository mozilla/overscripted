# %% [markdown]
# # Hello Mozfest!
#
# This notebook shows how to get set up with the Overscripted dataset. It covers working on a sample of the data in [Pandas](http://pandas.pydata.org/), and processing the full data in [Spark](https://spark.apache.org/docs/latest/api/python/pyspark.html).
#
# The [analysis README](https://github.com/mozilla/Overscripted-Data-Analysis-Challenge/tree/master/analyses) describes how to set up the environment with the necessary dependencies, including the Jupyter notebook. Specific packages are listed in the [environment.yaml](https://github.com/mozilla/Overscripted-Data-Analysis-Challenge/blob/master/analyses/environment.yaml).

# %%
import pandas as pd
import os.path

# %%
## Don't limit pandas display.
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", -1)

# %% [markdown]
# Specify the base dir where you have saved the dataset.

# %%
DATA_DIR = "../data/"  ## Change me

# %% [markdown]
# We are primarily interested in the `value` column, representing the value returned from each API call. We retain it and a few other relevant columns for analysis.

# %%
COLUMNS = [
    "location",  ## The URL of the page that was crawled
    "script_url",  ## The script where the call was made
    "symbol",  ## The JS API symbol
    "value",  ## The value returned
    "value_1000",  ## The value truncated to 1000 chars
    "value_len"  ## The number of chars in the full value string
]

# %% [markdown]
# ## Working with a sample in Pandas
#
# The sample dataset described in the [README](https://github.com/mozilla/Overscripted-Data-Analysis-Challenge) is small enough that we can load it into memory and explore it using Pandas.
#
# Download and unzip it into the data dir. Then load it as a Pandas DataFrame, restricted to the columns of interest.

# %%
SAMPLE_DATA_PARQUET = os.path.join(DATA_DIR,
                                   "sample",
                                   "part-00000-34d9b361-ea79-42eb-82ee-9c9f9259c339-c000.snappy.parquet")

# %%
df = pd.read_parquet(SAMPLE_DATA_PARQUET,
                     engine="pyarrow",
                     columns=COLUMNS)

# %%
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              location  \
# 0  https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
# 1  https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
# 2  https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
# 3  https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
# 4  https://cas.us.criteo.com/delivery/r/afr.php?did=5a34c73ff17390f0eaeb591979874b00&z=WjTHPwAHZYkKT7BIAAcskrRh4Qozh3b-c-mtZg&u=%7C7J5NcLNwKWZvhHazrdQ0r3pEybQM2VrhNSue519M%2FnU%3D%7C&c1=M5BADJe1UR3zJ2HNju9b10FggySKKMK0AoYTtPDcqDnSIQIZUQPlDupK--OP2eR-eNGQ46cgN3mwCl5UMg4IstlvomsUbHEHUzImPBAbL0KpTFeMsdEkBo28MAQVY_79HvMen3pU9pjoRxbnxk_AxatU3fdvCPtFY7Wzui5q962zi71J5i_HHNmYi7XbHxLl1v3NLOEqWiI-3QfHE1byzwOhuyge44QAJfUpukDSr4X723xUoquihjIy6b6D_yU9AsLHIIxKQk64_ES4G8moUw5dbt7SG3KWRhyjzAZW5acfRwaX8v33UzaCSZKj4O0XffzJaDiMmsprtAOP0J4xHPtfZqvurKt_x3z5y83mK1o&ct0=https://adclick.g.doubleclick.net/aclk%3Fsa%3Dl%26ai%3DCcqaRP8c0WonLHcjgvgKS2ZyADO7lmPBNsu23nZ0BwI23ARABIABgyQaCARdjYS1wdWItNTc4NzU5MjQ4Mzc2Njc2MKABrN3-6APIAQngAgCoAwGqBMUBT9DGnU9Xf5zpWjsp7PXxVDLu7mhvsOzx8jjeTb-wk_FUQNpBqVd4QxwydKBkX31VemFtAuP1QMeGjoHagpA44JfU11OU46ZLmBKcADPeCDg8kDPJvowA7EbbZ6gvml2aRO7nKo1LHNbLoGTBvP6gmhnbhVqThagbrECDM6qxbcRiiWobTKajDG8KeWma5flmrMZiQe5Lu3cyX_WMmu36IIP2lojiMZaZvgiE_ncYb24UZCKxrORb0gO54t1XHQFwzDnBRPXgBAGABufvkeKYhIzL9gGgBiGoB6a-G9gHANIIBQiAYRAB8ggbYWR4LXN1YnN5bi0wOTI1MDI4NTk2NjIxNjE3%26num%3D1%26sig%3DAOD64_1ibrZmc1pVLttz4doqoDmSHOvwXg%26client%3Dca-pub-5787592483766760%26adurl%3D
#
#                                                                                                                                   script_url  \
# 0  https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
# 1  https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
# 2  https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
# 3  https://staticxx.facebook.com/connect/xd_arbiter/r/lY4eZXm_YWu.js?version=42#channel=f30ef17b61f384&origin=http%3A%2F%2Fwww.ubitennis.com
# 4  https://ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js
#
#                        symbol  \
# 0  window.name
# 1  window.name
# 2  window.document.cookie
# 3  window.navigator.userAgent
# 4  window.navigator.userAgent
#
#                                                                   value  \
# 0  fb_xdm_frame_https
# 1  fb_xdm_frame_https
# 2
# 3  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0
# 4  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0
#
#                                                              value_1000  \
# 0  fb_xdm_frame_https
# 1  fb_xdm_frame_https
# 2
# 3  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0
# 4  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0
#
#    value_len
# 0  18
# 1  18
# 2  0
# 3  68
# 4  68

# %% [markdown]
# Restrict to operations that returned a value.

# %%
df = df[df.value_len > 0]

# %% [markdown]
# How many rows with values are there in the sample?

# %%
len(df)
# Out:
# 7314

# %% [markdown]
# How many unique values are there?

# %%
len(df.value.unique())
# Out:
# 1223

# %% [markdown]
# What are the symbols that returned values?

# %%
df.symbol.value_counts().sort_index()
# Out:
# CanvasRenderingContext2D.fillStyle                                       39
# CanvasRenderingContext2D.font                                            18
# CanvasRenderingContext2D.globalCompositeOperation                        2
# CanvasRenderingContext2D.lineWidth                                       10
# CanvasRenderingContext2D.shadowBlur                                      20
# CanvasRenderingContext2D.shadowColor                                     20
# CanvasRenderingContext2D.shadowOffsetX                                   20
# CanvasRenderingContext2D.shadowOffsetY                                   20
# CanvasRenderingContext2D.strokeStyle                                     4
# CanvasRenderingContext2D.textBaseline                                    7
# HTMLCanvasElement.height                                                 35
# HTMLCanvasElement.nodeName                                               2
# HTMLCanvasElement.nodeType                                               2
# HTMLCanvasElement.style                                                  16
# HTMLCanvasElement.width                                                  53
# RTCPeerConnection.localDescription                                       1
# RTCPeerConnection.onicecandidate                                         2
# window.Storage.length                                                    78
# window.document.cookie                                                   3189
# window.localStorage                                                      442
# window.name                                                              109
# window.navigator.appCodeName                                             3
# window.navigator.appName                                                 135
# window.navigator.appVersion                                              74
# window.navigator.buildID                                                 2
# window.navigator.cookieEnabled                                           45
# window.navigator.doNotTrack                                              21
# window.navigator.geolocation                                             2
# window.navigator.language                                                96
# window.navigator.languages                                               21
# window.navigator.mimeTypes[application/futuresplash].description         7
# window.navigator.mimeTypes[application/futuresplash].suffixes            9
# window.navigator.mimeTypes[application/futuresplash].type                13
# window.navigator.mimeTypes[application/x-shockwave-flash].description    7
# window.navigator.mimeTypes[application/x-shockwave-flash].suffixes       9
# window.navigator.mimeTypes[application/x-shockwave-flash].type           23
# window.navigator.onLine                                                  8
# window.navigator.oscpu                                                   2
# window.navigator.platform                                                120
# window.navigator.plugins[Shockwave Flash].description                    238
# window.navigator.plugins[Shockwave Flash].filename                       22
# window.navigator.plugins[Shockwave Flash].length                         10
# window.navigator.plugins[Shockwave Flash].name                           90
# window.navigator.plugins[Shockwave Flash].version                        10
# window.navigator.product                                                 43
# window.navigator.productSub                                              2
# window.navigator.userAgent                                               1797
# window.screen.colorDepth                                                 166
# window.screen.pixelDepth                                                 14
# window.sessionStorage                                                    236
# Name: symbol, dtype: int64

# %% [markdown]
# The dataset contains cookies that were accessed via the JS API (`window.document.cookie`). They are stored as key-value pairs of the form `<name>=<value>`, delimited by `;`. Note, however, that this only represents a subset of all cookies used, since we don't have visibility into those that are sent with each request.

# %%
df_cookies = df[df.symbol == "window.document.cookie"]

# %%
df_cookies.head()
# Out:
#                            location  \
# 50  https://www.syracuse.edu/about/
# 51  https://www.syracuse.edu/about/
# 52  https://www.syracuse.edu/about/
# 53  https://www.syracuse.edu/about/
# 54  https://www.syracuse.edu/about/
#
#                                        script_url                  symbol  \
# 50  https://www.google-analytics.com/analytics.js  window.document.cookie
# 51  https://www.google-analytics.com/analytics.js  window.document.cookie
# 52  https://www.google-analytics.com/analytics.js  window.document.cookie
# 53  https://www.google-analytics.com/analytics.js  window.document.cookie
# 54  https://www.google-analytics.com/analytics.js  window.document.cookie
#
#                                                                                                    value  \
# 50  _ga=GA1.2.1687044407.1513387667; path=/; expires=Mon, 16 Dec 2019 01:27:47 GMT; domain=syracuse.edu;
# 51  _ga=GA1.2.1687044407.1513387667
# 52  _ga=GA1.2.1687044407.1513387667
# 53  _ga=GA1.2.1687044407.1513387667
# 54  _gid=GA1.2.794143.1513387667; path=/; expires=Sun, 17 Dec 2017 01:27:47 GMT; domain=syracuse.edu;
#
#                                                                                               value_1000  \
# 50  _ga=GA1.2.1687044407.1513387667; path=/; expires=Mon, 16 Dec 2019 01:27:47 GMT; domain=syracuse.edu;
# 51  _ga=GA1.2.1687044407.1513387667
# 52  _ga=GA1.2.1687044407.1513387667
# 53  _ga=GA1.2.1687044407.1513387667
# 54  _gid=GA1.2.794143.1513387667; path=/; expires=Sun, 17 Dec 2017 01:27:47 GMT; domain=syracuse.edu;
#
#     value_len
# 50  100
# 51  31
# 52  31
# 53  31
# 54  97

# %% [markdown]
# How many cookie values are there in the sample?

# %%
len(df_cookies)
# Out:
# 3189

# %% [markdown]
# How many cookies were accessed in each call, and what is the distribution?

# %%
def parse_cookie_entries(contents):
    """Split value contents into '<name>=<value>' strings."""
    entries = contents.split(";")
    cleaned_entries = [e.strip() for e in entries if len(e) > 0]
    return cleaned_entries

# %%
cookie_num_entries = df_cookies.value.apply(lambda c: len(parse_cookie_entries(c)))

# %%
cookie_num_entries.value_counts().sort_index()
# Out:
# 1     158
# 2     308
# 3     363
# 4     681
# 5     180
# 6     174
# 7     154
# 8     48
# 9     115
# 10    67
# 11    44
# 12    77
# 13    58
# 14    114
# 15    67
# 16    107
# 17    96
# 18    59
# 19    61
# 20    13
# 21    23
# 22    10
# 23    13
# 24    6
# 25    14
# 26    21
# 27    22
# 28    2
# 29    16
# 30    3
# 31    5
# 32    23
# 33    3
# 34    84
# Name: value, dtype: int64

# %% [markdown]
# ## Working with the full dataset in Spark
#
# We use [findspark](https://github.com/minrk/findspark) to set up spark.

# %%
import findspark

findspark.init()  # Load Spark, handling necessary environment settings.

from pyspark import SparkContext
from pyspark.sql import SparkSession
import pyspark.sql.functions as fun

sc = SparkContext(appName="Overscripted")
spark = SparkSession(sc)

# %% [markdown]
# Download the full dataset and unzip into the data dir. It will be split across subdirs `0/`, `1/`, `2/`, `3/`. Read it into Spark, restricted to the columns of interest.

# %%
FULL_DATA_DIRS = ["0", "1", "2", "3"]

# %%
sdf = spark.read.option("mergeSchema", "true")\
    .parquet(*[os.path.join(DATA_DIR, d) for d in FULL_DATA_DIRS])

# %%
sdf = sdf.select(COLUMNS)

# %% [markdown]
# The `value` column in the full dataset has some extremely long strings that cause problems when scanning the dataset. For now, we drop this and work with the `value_1000` column instead.

# %%
sdf = sdf.drop("value")

# %%
sdf.limit(5).toPandas()
# Out:
#                                                               location  \
# 0  https://tramites.saime.gob.ve/index.php?r=verificacion/verificacion
# 1  https://tramites.saime.gob.ve/index.php?r=verificacion/verificacion
# 2  https://tramites.saime.gob.ve/index.php?r=verificacion/verificacion
# 3  https://tramites.saime.gob.ve/index.php?r=verificacion/verificacion
# 4  https://tramites.saime.gob.ve/index.php?r=verificacion/verificacion
#
#                                                               script_url  \
# 0  https://tramites.saime.gob.ve/assets/e5116c7f/jquery.min.js
# 1  https://tramites.saime.gob.ve/assets/e5116c7f/jui/js/jquery-ui.min.js
# 2  https://tramites.saime.gob.ve/themes/saime/js/jquery.ui.js
# 3  https://www.google-analytics.com/analytics.js
# 4  https://www.google-analytics.com/analytics.js
#
#                                            symbol  \
# 0  window.navigator.userAgent
# 1  window.navigator.userAgent
# 2  window.navigator.userAgent
# 3  window.screen.colorDepth
# 4  window.navigator.plugins[Shockwave Flash].name
#
#                                                              value_1000  \
# 0  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0
# 1  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0
# 2  Mozilla/5.0 (X11; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0
# 3  24
# 4  Shockwave Flash
#
#    value_len
# 0  68
# 1  68
# 2  68
# 3  2
# 4  15

# %% [markdown]
# Restrict to operations that returned a value.

# %%
sdf = sdf.where("value_len > 0")

# %% [markdown]
# How many rows with values are there in the dataset?

# %%
def fmt(num):
    print(format(num, ","))

# %%
fmt(sdf.count())
# Out:
# 84,786,487

# %% [markdown]
# What are the symbols that returned values?

# %%
sdf.groupBy("symbol").count()\
    .orderBy("symbol")\
    .toPandas()
# Out:
#                                                                     symbol  \
# 0    AnalyserNode.channelCount
# 1    AnalyserNode.channelCountMode
# 2    AnalyserNode.channelInterpretation
# 3    AnalyserNode.fftSize
# 4    AnalyserNode.frequencyBinCount
# 5    AnalyserNode.maxDecibels
# 6    AnalyserNode.minDecibels
# 7    AnalyserNode.numberOfInputs
# 8    AnalyserNode.numberOfOutputs
# 9    AnalyserNode.smoothingTimeConstant
# 10   AudioContext.currentTime
# 11   AudioContext.destination
# 12   AudioContext.listener
# 13   AudioContext.onstatechange
# 14   AudioContext.sampleRate
# 15   AudioContext.state
# 16   CanvasRenderingContext2D.__proto__
# 17   CanvasRenderingContext2D.ellipse
# 18   CanvasRenderingContext2D.fillStyle
# 19   CanvasRenderingContext2D.fillText
# 20   CanvasRenderingContext2D.filter
# 21   CanvasRenderingContext2D.font
# 22   CanvasRenderingContext2D.globalCompositeOperation
# 23   CanvasRenderingContext2D.imageSmoothingEnabled
# 24   CanvasRenderingContext2D.lineCap
# 25   CanvasRenderingContext2D.lineDashOffset
# 26   CanvasRenderingContext2D.lineJoin
# 27   CanvasRenderingContext2D.lineWidth
# 28   CanvasRenderingContext2D.measureText
# 29   CanvasRenderingContext2D.miterLimit
# 30   CanvasRenderingContext2D.mozCurrentTransform
# 31   CanvasRenderingContext2D.mozCurrentTransformInverse
# 32   CanvasRenderingContext2D.mozImageSmoothingEnabled
# 33   CanvasRenderingContext2D.restore
# 34   CanvasRenderingContext2D.save
# 35   CanvasRenderingContext2D.scale
# 36   CanvasRenderingContext2D.shadowBlur
# 37   CanvasRenderingContext2D.shadowColor
# 38   CanvasRenderingContext2D.shadowOffsetX
# 39   CanvasRenderingContext2D.shadowOffsetY
# 40   CanvasRenderingContext2D.stroke
# 41   CanvasRenderingContext2D.strokeStyle
# 42   CanvasRenderingContext2D.strokeText
# 43   CanvasRenderingContext2D.textAlign
# 44   CanvasRenderingContext2D.textBaseline
# 45   GainNode.gain
# 46   GainNode.numberOfOutputs
# 47   HTMLCanvasElement.DOCUMENT_NODE
# 48   HTMLCanvasElement.__proto__
# 49   HTMLCanvasElement.addEventListener
# 50   HTMLCanvasElement.append
# 51   HTMLCanvasElement.attributes
# 52   HTMLCanvasElement.blur
# 53   HTMLCanvasElement.childElementCount
# 54   HTMLCanvasElement.childNodes
# 55   HTMLCanvasElement.children
# 56   HTMLCanvasElement.classList
# 57   HTMLCanvasElement.className
# 58   HTMLCanvasElement.clientHeight
# 59   HTMLCanvasElement.clientLeft
# 60   HTMLCanvasElement.clientTop
# 61   HTMLCanvasElement.clientWidth
# 62   HTMLCanvasElement.constructor
# 63   HTMLCanvasElement.dataset
# 64   HTMLCanvasElement.dir
# 65   HTMLCanvasElement.draggable
# 66   HTMLCanvasElement.firstChild
# 67   HTMLCanvasElement.firstElementChild
# 68   HTMLCanvasElement.getContext
# 69   HTMLCanvasElement.height
# 70   HTMLCanvasElement.id
# 71   HTMLCanvasElement.innerHTML
# 72   HTMLCanvasElement.lastChild
# 73   HTMLCanvasElement.localName
# 74   HTMLCanvasElement.mozOpaque
# 75   HTMLCanvasElement.namespaceURI
# 76   HTMLCanvasElement.nextElementSibling
# 77   HTMLCanvasElement.nextSibling
# 78   HTMLCanvasElement.nodeName
# 79   HTMLCanvasElement.nodeType
# 80   HTMLCanvasElement.offsetHeight
# 81   HTMLCanvasElement.offsetLeft
# 82   HTMLCanvasElement.offsetParent
# 83   HTMLCanvasElement.offsetTop
# 84   HTMLCanvasElement.offsetWidth
# 85   HTMLCanvasElement.onblur
# 86   HTMLCanvasElement.onchange
# 87   HTMLCanvasElement.onclick
# 88   HTMLCanvasElement.oncontextmenu
# 89   HTMLCanvasElement.oncut
# 90   HTMLCanvasElement.ondblclick
# 91   HTMLCanvasElement.ondragenter
# 92   HTMLCanvasElement.ondragleave
# 93   HTMLCanvasElement.ondragover
# 94   HTMLCanvasElement.ondragstart
# 95   HTMLCanvasElement.ondrop
# 96   HTMLCanvasElement.onfocus
# 97   HTMLCanvasElement.onkeydown
# 98   HTMLCanvasElement.onkeypress
# 99   HTMLCanvasElement.onkeyup
# 100  HTMLCanvasElement.onload
# 101  HTMLCanvasElement.onmousedown
# 102  HTMLCanvasElement.onmouseenter
# 103  HTMLCanvasElement.onmouseleave
# 104  HTMLCanvasElement.onmousemove
# 105  HTMLCanvasElement.onmouseout
# 106  HTMLCanvasElement.onmouseover
# 107  HTMLCanvasElement.onmouseup
# 108  HTMLCanvasElement.onpaste
# 109  HTMLCanvasElement.onresize
# 110  HTMLCanvasElement.onselectstart
# 111  HTMLCanvasElement.onwheel
# 112  HTMLCanvasElement.outerHTML
# 113  HTMLCanvasElement.ownerDocument
# 114  HTMLCanvasElement.parentElement
# 115  HTMLCanvasElement.parentNode
# 116  HTMLCanvasElement.previousElementSibling
# 117  HTMLCanvasElement.previousSibling
# 118  HTMLCanvasElement.remove
# 119  HTMLCanvasElement.removeAttribute
# 120  HTMLCanvasElement.removeEventListener
# 121  HTMLCanvasElement.requestPointerLock
# 122  HTMLCanvasElement.scrollHeight
# 123  HTMLCanvasElement.scrollLeft
# 124  HTMLCanvasElement.scrollTop
# 125  HTMLCanvasElement.scrollWidth
# 126  HTMLCanvasElement.setAttribute
# 127  HTMLCanvasElement.style
# 128  HTMLCanvasElement.tabIndex
# 129  HTMLCanvasElement.tagName
# 130  HTMLCanvasElement.toBlob
# 131  HTMLCanvasElement.toString
# 132  HTMLCanvasElement.width
# 133  OfflineAudioContext.destination
# 134  OfflineAudioContext.oncomplete
# 135  OscillatorNode.frequency
# 136  OscillatorNode.start
# 137  OscillatorNode.stop
# 138  OscillatorNode.type
# 139  RTCPeerConnection.addEventListener
# 140  RTCPeerConnection.addIceCandidate
# 141  RTCPeerConnection.getStats
# 142  RTCPeerConnection.iceConnectionState
# 143  RTCPeerConnection.iceGatheringState
# 144  RTCPeerConnection.idpLoginUrl
# 145  RTCPeerConnection.localDescription
# 146  RTCPeerConnection.onaddstream
# 147  RTCPeerConnection.onicecandidate
# 148  RTCPeerConnection.oniceconnectionstatechange
# 149  RTCPeerConnection.onremovestream
# 150  RTCPeerConnection.onsignalingstatechange
# 151  RTCPeerConnection.peerIdentity
# 152  RTCPeerConnection.remoteDescription
# 153  RTCPeerConnection.removeEventListener
# 154  RTCPeerConnection.setLocalDescription
# 155  RTCPeerConnection.setRemoteDescription
# 156  RTCPeerConnection.signalingState
# 157  ScriptProcessorNode.onaudioprocess
# 158  window.Storage.clear
# 159  window.Storage.getItem
# 160  window.Storage.length
# 161  window.Storage.setItem
# 162  window.document.cookie
# 163  window.localStorage
# 164  window.name
# 165  window.navigator.appCodeName
# 166  window.navigator.appName
# 167  window.navigator.appVersion
# 168  window.navigator.buildID
# 169  window.navigator.cookieEnabled
# 170  window.navigator.doNotTrack
# 171  window.navigator.geolocation
# 172  window.navigator.language
# 173  window.navigator.languages
# 174  window.navigator.mimeTypes[application/futuresplash].description
# 175  window.navigator.mimeTypes[application/futuresplash].suffixes
# 176  window.navigator.mimeTypes[application/futuresplash].type
# 177  window.navigator.mimeTypes[application/x-shockwave-flash].description
# 178  window.navigator.mimeTypes[application/x-shockwave-flash].suffixes
# 179  window.navigator.mimeTypes[application/x-shockwave-flash].type
# 180  window.navigator.onLine
# 181  window.navigator.oscpu
# 182  window.navigator.platform
# 183  window.navigator.plugins[Shockwave Flash].description
# 184  window.navigator.plugins[Shockwave Flash].filename
# 185  window.navigator.plugins[Shockwave Flash].length
# 186  window.navigator.plugins[Shockwave Flash].name
# 187  window.navigator.plugins[Shockwave Flash].version
# 188  window.navigator.product
# 189  window.navigator.productSub
# 190  window.navigator.userAgent
# 191  window.screen.colorDepth
# 192  window.screen.pixelDepth
# 193  window.sessionStorage
#
#         count
# 0    3
# 1    3
# 2    3
# 3    774
# 4    770
# 5    771
# 6    769
# 7    3
# 8    3
# 9    770
# 10   354
# 11   3758
# 12   1230
# 13   745
# 14   882
# 15   1249
# 16   3
# 17   60
# 18   1957479
# 19   58
# 20   2
# 21   814135
# 22   122162
# 23   9722
# 24   149511
# 25   7726
# 26   151407
# 27   718195
# 28   58
# 29   102589
# 30   3102
# 31   1890
# 32   6561
# 33   332
# 34   332
# 35   3
# 36   172805
# 37   158575
# 38   159260
# 39   161443
# 40   18
# 41   650205
# 42   84
# 43   246380
# 44   293484
# 45   1112
# 46   7
# 47   4
# 48   1028
# 49   267
# 50   227
# 51   4507
# 52   26
# 53   11
# 54   2541
# 55   1795
# 56   22963
# 57   23058
# 58   20665
# 59   4
# 60   4
# 61   20341
# 62   9246
# 63   15
# 64   28
# 65   9558
# 66   4897
# 67   3586
# 68   37
# 69   644464
# 70   8457
# 71   1
# 72   1
# 73   4577
# 74   1687
# 75   13
# 76   3560
# 77   3857
# 78   67621
# 79   153630
# 80   6175
# 81   2096
# 82   1499
# 83   1812
# 84   7346
# 85   128
# 86   125
# 87   466
# 88   152
# 89   125
# 90   126
# 91   125
# 92   125
# 93   125
# 94   50
# 95   125
# 96   128
# 97   132
# 98   128
# 99   129
# 100  125
# 101  310
# 102  125
# 103  127
# 104  1538
# 105  232
# 106  229
# 107  227
# 108  125
# 109  125
# 110  12054
# 111  4
# 112  6
# 113  37831
# 114  136
# 115  57191
# 116  23
# 117  139
# 118  2
# 119  385
# 120  267
# 121  15
# 122  3
# 123  60
# 124  60
# 125  3
# 126  385
# 127  294217
# 128  43
# 129  14475
# 130  342
# 131  246
# 132  680991
# 133  1380
# 134  1380
# 135  3056
# 136  351
# 137  351
# 138  2011
# 139  346
# 140  726
# 141  361
# 142  33
# 143  13984
# 144  6556
# 145  88683
# 146  3
# 147  32522
# 148  16
# 149  6556
# 150  16
# 151  6556
# 152  13113
# 153  346
# 154  363
# 155  363
# 156  13160
# 157  287
# 158  22
# 159  102
# 160  540926
# 161  26
# 162  34124552
# 163  8765570
# 164  1639851
# 165  51151
# 166  1286058
# 167  707269
# 168  23409
# 169  692501
# 170  468329
# 171  43012
# 172  1172212
# 173  199425
# 174  70273
# 175  94020
# 176  150359
# 177  70279
# 178  94025
# 179  213764
# 180  116031
# 181  54789
# 182  1140728
# 183  1863265
# 184  225741
# 185  184980
# 186  895264
# 187  144656
# 188  279631
# 189  71117
# 190  15534211
# 191  1449837
# 192  156289
# 193  4033673

# %% [markdown]
# How many of the values are numeric (integer)?

# %%
sdf = sdf.withColumn("value_is_numeric",
                     sdf.value_1000.cast("int").isNotNull())

# %%
sdf.groupBy("value_is_numeric").count().toPandas()
# Out:
#    value_is_numeric     count
# 0  True              5452728
# 1  False             79333759

# %% [markdown]
# How are these distributed across the symbols?

# %%
sdf.groupBy("symbol").pivot("value_is_numeric").count()\
    .fillna(0)\
    .orderBy("symbol")\
    .toPandas()
# Out:
#                                                                     symbol  \
# 0    AnalyserNode.channelCount
# 1    AnalyserNode.channelCountMode
# 2    AnalyserNode.channelInterpretation
# 3    AnalyserNode.fftSize
# 4    AnalyserNode.frequencyBinCount
# 5    AnalyserNode.maxDecibels
# 6    AnalyserNode.minDecibels
# 7    AnalyserNode.numberOfInputs
# 8    AnalyserNode.numberOfOutputs
# 9    AnalyserNode.smoothingTimeConstant
# 10   AudioContext.currentTime
# 11   AudioContext.destination
# 12   AudioContext.listener
# 13   AudioContext.onstatechange
# 14   AudioContext.sampleRate
# 15   AudioContext.state
# 16   CanvasRenderingContext2D.__proto__
# 17   CanvasRenderingContext2D.ellipse
# 18   CanvasRenderingContext2D.fillStyle
# 19   CanvasRenderingContext2D.fillText
# 20   CanvasRenderingContext2D.filter
# 21   CanvasRenderingContext2D.font
# 22   CanvasRenderingContext2D.globalCompositeOperation
# 23   CanvasRenderingContext2D.imageSmoothingEnabled
# 24   CanvasRenderingContext2D.lineCap
# 25   CanvasRenderingContext2D.lineDashOffset
# 26   CanvasRenderingContext2D.lineJoin
# 27   CanvasRenderingContext2D.lineWidth
# 28   CanvasRenderingContext2D.measureText
# 29   CanvasRenderingContext2D.miterLimit
# 30   CanvasRenderingContext2D.mozCurrentTransform
# 31   CanvasRenderingContext2D.mozCurrentTransformInverse
# 32   CanvasRenderingContext2D.mozImageSmoothingEnabled
# 33   CanvasRenderingContext2D.restore
# 34   CanvasRenderingContext2D.save
# 35   CanvasRenderingContext2D.scale
# 36   CanvasRenderingContext2D.shadowBlur
# 37   CanvasRenderingContext2D.shadowColor
# 38   CanvasRenderingContext2D.shadowOffsetX
# 39   CanvasRenderingContext2D.shadowOffsetY
# 40   CanvasRenderingContext2D.stroke
# 41   CanvasRenderingContext2D.strokeStyle
# 42   CanvasRenderingContext2D.strokeText
# 43   CanvasRenderingContext2D.textAlign
# 44   CanvasRenderingContext2D.textBaseline
# 45   GainNode.gain
# 46   GainNode.numberOfOutputs
# 47   HTMLCanvasElement.DOCUMENT_NODE
# 48   HTMLCanvasElement.__proto__
# 49   HTMLCanvasElement.addEventListener
# 50   HTMLCanvasElement.append
# 51   HTMLCanvasElement.attributes
# 52   HTMLCanvasElement.blur
# 53   HTMLCanvasElement.childElementCount
# 54   HTMLCanvasElement.childNodes
# 55   HTMLCanvasElement.children
# 56   HTMLCanvasElement.classList
# 57   HTMLCanvasElement.className
# 58   HTMLCanvasElement.clientHeight
# 59   HTMLCanvasElement.clientLeft
# 60   HTMLCanvasElement.clientTop
# 61   HTMLCanvasElement.clientWidth
# 62   HTMLCanvasElement.constructor
# 63   HTMLCanvasElement.dataset
# 64   HTMLCanvasElement.dir
# 65   HTMLCanvasElement.draggable
# 66   HTMLCanvasElement.firstChild
# 67   HTMLCanvasElement.firstElementChild
# 68   HTMLCanvasElement.getContext
# 69   HTMLCanvasElement.height
# 70   HTMLCanvasElement.id
# 71   HTMLCanvasElement.innerHTML
# 72   HTMLCanvasElement.lastChild
# 73   HTMLCanvasElement.localName
# 74   HTMLCanvasElement.mozOpaque
# 75   HTMLCanvasElement.namespaceURI
# 76   HTMLCanvasElement.nextElementSibling
# 77   HTMLCanvasElement.nextSibling
# 78   HTMLCanvasElement.nodeName
# 79   HTMLCanvasElement.nodeType
# 80   HTMLCanvasElement.offsetHeight
# 81   HTMLCanvasElement.offsetLeft
# 82   HTMLCanvasElement.offsetParent
# 83   HTMLCanvasElement.offsetTop
# 84   HTMLCanvasElement.offsetWidth
# 85   HTMLCanvasElement.onblur
# 86   HTMLCanvasElement.onchange
# 87   HTMLCanvasElement.onclick
# 88   HTMLCanvasElement.oncontextmenu
# 89   HTMLCanvasElement.oncut
# 90   HTMLCanvasElement.ondblclick
# 91   HTMLCanvasElement.ondragenter
# 92   HTMLCanvasElement.ondragleave
# 93   HTMLCanvasElement.ondragover
# 94   HTMLCanvasElement.ondragstart
# 95   HTMLCanvasElement.ondrop
# 96   HTMLCanvasElement.onfocus
# 97   HTMLCanvasElement.onkeydown
# 98   HTMLCanvasElement.onkeypress
# 99   HTMLCanvasElement.onkeyup
# 100  HTMLCanvasElement.onload
# 101  HTMLCanvasElement.onmousedown
# 102  HTMLCanvasElement.onmouseenter
# 103  HTMLCanvasElement.onmouseleave
# 104  HTMLCanvasElement.onmousemove
# 105  HTMLCanvasElement.onmouseout
# 106  HTMLCanvasElement.onmouseover
# 107  HTMLCanvasElement.onmouseup
# 108  HTMLCanvasElement.onpaste
# 109  HTMLCanvasElement.onresize
# 110  HTMLCanvasElement.onselectstart
# 111  HTMLCanvasElement.onwheel
# 112  HTMLCanvasElement.outerHTML
# 113  HTMLCanvasElement.ownerDocument
# 114  HTMLCanvasElement.parentElement
# 115  HTMLCanvasElement.parentNode
# 116  HTMLCanvasElement.previousElementSibling
# 117  HTMLCanvasElement.previousSibling
# 118  HTMLCanvasElement.remove
# 119  HTMLCanvasElement.removeAttribute
# 120  HTMLCanvasElement.removeEventListener
# 121  HTMLCanvasElement.requestPointerLock
# 122  HTMLCanvasElement.scrollHeight
# 123  HTMLCanvasElement.scrollLeft
# 124  HTMLCanvasElement.scrollTop
# 125  HTMLCanvasElement.scrollWidth
# 126  HTMLCanvasElement.setAttribute
# 127  HTMLCanvasElement.style
# 128  HTMLCanvasElement.tabIndex
# 129  HTMLCanvasElement.tagName
# 130  HTMLCanvasElement.toBlob
# 131  HTMLCanvasElement.toString
# 132  HTMLCanvasElement.width
# 133  OfflineAudioContext.destination
# 134  OfflineAudioContext.oncomplete
# 135  OscillatorNode.frequency
# 136  OscillatorNode.start
# 137  OscillatorNode.stop
# 138  OscillatorNode.type
# 139  RTCPeerConnection.addEventListener
# 140  RTCPeerConnection.addIceCandidate
# 141  RTCPeerConnection.getStats
# 142  RTCPeerConnection.iceConnectionState
# 143  RTCPeerConnection.iceGatheringState
# 144  RTCPeerConnection.idpLoginUrl
# 145  RTCPeerConnection.localDescription
# 146  RTCPeerConnection.onaddstream
# 147  RTCPeerConnection.onicecandidate
# 148  RTCPeerConnection.oniceconnectionstatechange
# 149  RTCPeerConnection.onremovestream
# 150  RTCPeerConnection.onsignalingstatechange
# 151  RTCPeerConnection.peerIdentity
# 152  RTCPeerConnection.remoteDescription
# 153  RTCPeerConnection.removeEventListener
# 154  RTCPeerConnection.setLocalDescription
# 155  RTCPeerConnection.setRemoteDescription
# 156  RTCPeerConnection.signalingState
# 157  ScriptProcessorNode.onaudioprocess
# 158  window.Storage.clear
# 159  window.Storage.getItem
# 160  window.Storage.length
# 161  window.Storage.setItem
# 162  window.document.cookie
# 163  window.localStorage
# 164  window.name
# 165  window.navigator.appCodeName
# 166  window.navigator.appName
# 167  window.navigator.appVersion
# 168  window.navigator.buildID
# 169  window.navigator.cookieEnabled
# 170  window.navigator.doNotTrack
# 171  window.navigator.geolocation
# 172  window.navigator.language
# 173  window.navigator.languages
# 174  window.navigator.mimeTypes[application/futuresplash].description
# 175  window.navigator.mimeTypes[application/futuresplash].suffixes
# 176  window.navigator.mimeTypes[application/futuresplash].type
# 177  window.navigator.mimeTypes[application/x-shockwave-flash].description
# 178  window.navigator.mimeTypes[application/x-shockwave-flash].suffixes
# 179  window.navigator.mimeTypes[application/x-shockwave-flash].type
# 180  window.navigator.onLine
# 181  window.navigator.oscpu
# 182  window.navigator.platform
# 183  window.navigator.plugins[Shockwave Flash].description
# 184  window.navigator.plugins[Shockwave Flash].filename
# 185  window.navigator.plugins[Shockwave Flash].length
# 186  window.navigator.plugins[Shockwave Flash].name
# 187  window.navigator.plugins[Shockwave Flash].version
# 188  window.navigator.product
# 189  window.navigator.productSub
# 190  window.navigator.userAgent
# 191  window.screen.colorDepth
# 192  window.screen.pixelDepth
# 193  window.sessionStorage
#
#         false     true
# 0    0         3
# 1    3         0
# 2    3         0
# 3    0         774
# 4    0         770
# 5    0         771
# 6    0         769
# 7    0         3
# 8    0         3
# 9    0         770
# 10   0         354
# 11   3758      0
# 12   1230      0
# 13   745       0
# 14   0         882
# 15   1249      0
# 16   3         0
# 17   60        0
# 18   1956639   840
# 19   58        0
# 20   2         0
# 21   814134    1
# 22   122162    0
# 23   9722      0
# 24   149511    0
# 25   0         7726
# 26   151407    0
# 27   277       717918
# 28   58        0
# 29   0         102589
# 30   3102      0
# 31   1890      0
# 32   6561      0
# 33   332       0
# 34   332       0
# 35   0         3
# 36   165       172640
# 37   158445    130
# 38   174       159086
# 39   174       161269
# 40   18        0
# 41   650105    100
# 42   84        0
# 43   246368    12
# 44   293484    0
# 45   1112      0
# 46   0         7
# 47   0         4
# 48   1028      0
# 49   267       0
# 50   227       0
# 51   4507      0
# 52   26        0
# 53   0         11
# 54   2541      0
# 55   1795      0
# 56   22963     0
# 57   23058     0
# 58   0         20665
# 59   0         4
# 60   0         4
# 61   0         20341
# 62   9246      0
# 63   15        0
# 64   28        0
# 65   9558      0
# 66   4897      0
# 67   3586      0
# 68   37        0
# 69   18        644446
# 70   8457      0
# 71   1         0
# 72   1         0
# 73   4577      0
# 74   1687      0
# 75   13        0
# 76   3560      0
# 77   3857      0
# 78   67621     0
# 79   0         153630
# 80   0         6175
# 81   0         2096
# 82   1499      0
# 83   0         1812
# 84   0         7346
# 85   128       0
# 86   125       0
# 87   466       0
# 88   152       0
# 89   125       0
# 90   126       0
# 91   125       0
# 92   125       0
# 93   125       0
# 94   50        0
# 95   125       0
# 96   128       0
# 97   132       0
# 98   128       0
# 99   129       0
# 100  125       0
# 101  310       0
# 102  125       0
# 103  127       0
# 104  1538      0
# 105  232       0
# 106  229       0
# 107  227       0
# 108  125       0
# 109  125       0
# 110  12054     0
# 111  4         0
# 112  6         0
# 113  37831     0
# 114  136       0
# 115  57191     0
# 116  23        0
# 117  139       0
# 118  2         0
# 119  385       0
# 120  267       0
# 121  15        0
# 122  0         3
# 123  0         60
# 124  0         60
# 125  0         3
# 126  385       0
# 127  294217    0
# 128  0         43
# 129  14475     0
# 130  342       0
# 131  246       0
# 132  24        680967
# 133  1380      0
# 134  1380      0
# 135  3056      0
# 136  351       0
# 137  351       0
# 138  2011      0
# 139  346       0
# 140  726       0
# 141  361       0
# 142  33        0
# 143  13984     0
# 144  6556      0
# 145  88683     0
# 146  3         0
# 147  32522     0
# 148  16        0
# 149  6556      0
# 150  16        0
# 151  6556      0
# 152  13113     0
# 153  346       0
# 154  363       0
# 155  363       0
# 156  13160     0
# 157  287       0
# 158  22        0
# 159  102       0
# 160  0         540926
# 161  26        0
# 162  34124547  5
# 163  8765570   0
# 164  1455367   184484
# 165  51151     0
# 166  1286058   0
# 167  707269    0
# 168  23409     0
# 169  692501    0
# 170  468329    0
# 171  43012     0
# 172  1172212   0
# 173  199425    0
# 174  70273     0
# 175  94020     0
# 176  150359    0
# 177  70279     0
# 178  94025     0
# 179  213764    0
# 180  116031    0
# 181  54789     0
# 182  1140728   0
# 183  1863265   0
# 184  225741    0
# 185  0         184980
# 186  895264    0
# 187  144656    0
# 188  279631    0
# 189  0         71117
# 190  15534211  0
# 191  0         1449837
# 192  0         156289
# 193  4033673   0
